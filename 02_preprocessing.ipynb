# %% [markdown]
# <a href="https://colab.research.google.com/github/satyamkarn100-ctrl/Neural-Recommendation-Personalization-Engine/blob/main/02_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install -q huggingface_hub
from huggingface_hub import hf_hub_download
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>LB28-NTMR</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>Satyamkarn100</b> (token: <code>oauth-Satyamkarn100</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
reviews_path = hf_hub_download(
    repo_id="Satyamkarn100/NeuraRec-Electronics",
    filename="raw/reviews.parquet",
    repo_type="dataset"
)
# Out:
# raw/reviews.parquet: reconstructing file:   0%|          |  0.00B /  313MB
# raw/reviews.parquet: downloading bytes:           |  0.00B

# %%
reviews = pd.read_parquet(reviews_path)
print('Reviews Shape:',reviews.shape)
# Out:
# Reviews Shape: (15473536, 4)

# %%
reviews.head()
# Out:
#                         user_id parent_asin  rating      timestamp
# 0  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B0047T79VS     3.0  1344406083000
# 1  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B01HHURN3W     3.0  1408995743000
# 2  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B00L0YLRUW     1.0  1439226089000
# 3  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B017T99JPG     5.0  1456772365000
# 4  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B01LW71IBJ     5.0  1456772571000

# %%
reviews['datetime'] = pd.to_datetime(
    reviews['timestamp'],unit='ms'
)

# %%
print(reviews['parent_asin'].nunique())
print()
reviews.head(10)
# Out:
# 368228
#                         user_id parent_asin  rating      timestamp  \
# 0  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B0047T79VS     3.0  1344406083000
# 1  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B01HHURN3W     3.0  1408995743000
# 2  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B00L0YLRUW     1.0  1439226089000
# 3  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B017T99JPG     5.0  1456772365000
# 4  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B01LW71IBJ     5.0  1456772571000
# 5  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B09S6Y5BRG     5.0  1541356831659
# 6  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B07BHHB5RH     5.0  1565130879386
# 7  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ  B07CML419K     5.0  1637522881041
# 8  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ  B013KPXNSW     5.0  1453856042000
# 9  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ  B08P3VMW76     5.0  1483327495000
#
#                  datetime
# 0 2012-08-08 06:08:03.000
# 1 2014-08-25 19:42:23.000
# 2 2015-08-10 17:01:29.000
# 3 2016-02-29 18:59:25.000
# 4 2016-02-29 19:02:51.000
# 5 2018-11-04 18:40:31.659
# 6 2019-08-06 22:34:39.386
# 7 2021-11-21 19:28:01.041
# 8 2016-01-27 00:54:02.000
# 9 2017-01-02 03:24:55.000

# %%
meta_paths = []

for i in range(1, 11):
    path = hf_hub_download(
        repo_id="Satyamkarn100/NeuraRec-Electronics",
        filename=f"raw/meta{i}.parquet",
        repo_type="dataset"
    )
    meta_paths.append(path)

print("Downloaded:", len(meta_paths), "files")
# Out:
# raw/meta1.parquet: reconstructing file:   0%|          |  0.00B /  147MB
# raw/meta1.parquet: downloading bytes:           |  0.00B
# raw/meta2.parquet: reconstructing file:   0%|          |  0.00B /  145MB
# raw/meta2.parquet: downloading bytes:           |  0.00B
# raw/meta3.parquet: reconstructing file:   0%|          |  0.00B /  143MB
# raw/meta3.parquet: downloading bytes:           |  0.00B
# raw/meta4.parquet: reconstructing file:   0%|          |  0.00B /  141MB
# raw/meta4.parquet: downloading bytes:           |  0.00B
# raw/meta5.parquet: reconstructing file:   0%|          |  0.00B /  139MB
# raw/meta5.parquet: downloading bytes:           |  0.00B
# raw/meta6.parquet: reconstructing file:   0%|          |  0.00B /  134MB
# raw/meta6.parquet: downloading bytes:           |  0.00B
# raw/meta7.parquet: reconstructing file:   0%|          |  0.00B /  131MB
# raw/meta7.parquet: downloading bytes:           |  0.00B
# raw/meta8.parquet: reconstructing file:   0%|          |  0.00B /  134MB
# raw/meta8.parquet: downloading bytes:           |  0.00B
# raw/meta9.parquet: reconstructing file:   0%|          |  0.00B /  131MB
# raw/meta9.parquet: downloading bytes:           |  0.00B
# raw/meta10.parquet: reconstructing file:   0%|          |  0.00B /  126MB
# raw/meta10.parquet: downloading bytes:           |  0.00B
# Downloaded: 10 files

# %%
meta = pd.concat(
    [pd.read_parquet(path) for path in meta_paths],
    ignore_index=True
)

print("Meta-Data Shape:", meta.shape)
meta.head()
# Out:
# Meta-Data Shape: (1610012, 10)
#                main_category  \
# 0            All Electronics
# 1            All Electronics
# 2                  Computers
# 3             AMAZON FASHION
# 4  Cell Phones & Accessories
#
#                                                title  average_rating  \
# 0             FS-1051 FATSHARK TELEPORTER V3 HEADSET             3.5
# 1                      Ce-H22B12-S1 4Kx2K Hdmi 4Port             5.0
# 2  Digi-Tatoo Decal Skin Compatible With MacBook ...             4.5
# 3  NotoCity Compatible with Vivoactive 4 band 22m...             4.5
# 4             Motorola Droid X Essentials Combo Pack             3.8
#
#    rating_number                                           features  \
# 0              6                                                 []
# 1              1             [UPC: 662774021904, Weight: 0.600 lbs]
# 2            246  [WARNING: Please IDENTIFY MODEL NUMBER on the ...
# 3            233  [☛NotoCity 22mm band is designed for Vivoactiv...
# 4             64  [New Droid X Essentials Combo Pack, Exclusive ...
#
#                                          description       store  \
# 0  [Teleporter V3 The “Teleporter V3” kit sets a ...   Fat Shark
# 1                               [HDMI In - HDMI Out]        SIIG
# 2                                                 []  Digi-Tatoo
# 3                                                 []    NotoCity
# 4  [all Genuine High Quality Motorola Made Access...     Verizon
#
#                                           categories  \
# 0   [Electronics, Television & Video, Video Glasses]
# 1  [Electronics, Television & Video, Accessories,...
# 2  [Electronics, Computers & Accessories, Laptop ...
# 3  [Electronics, Wearable Technology, Clips, Arm ...
# 4  [Electronics, Computers & Accessories, Compute...
#
#                                              details parent_asin
# 0  {"Date First Available": "August 2, 2014", "Ma...  B00MCW7G9M
# 1  {"Product Dimensions": "0.83 x 4.17 x 2.05 inc...  B00YT6XQSE
# 2  {"Brand": "Digi-Tatoo", "Color": "Fresh Marble...  B07SM135LS
# 3  {"Date First Available": "May 29, 2020", "Manu...  B089CNGZCW
# 4  {"Product Dimensions": "11.6 x 6.9 x 3.1 inche...  B004E2Z88O

# %%
print("Metadata Shape:", meta.shape)
print("\nColumns:")
print(meta.columns.tolist())

print("\nData Types:")
print(meta.dtypes)

print("\nInfo:")
meta.info()
# Out:
# Metadata Shape: (1610012, 10)
#
# Columns:
# ['main_category', 'title', 'average_rating', 'rating_number', 'features', 'description', 'store', 'categories', 'details', 'parent_asin']
#
# Data Types:
# main_category      object
# title              object
# average_rating    float64
# rating_number       int64
# features           object
# description        object
# store              object
# categories         object
# details            object
# parent_asin        object
# dtype: object
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610012 entries, 0 to 1610011
# Data columns (total 10 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   main_category   1503678 non-null  object
#  1   title           1610012 non-null  object
#  2   average_rating  1610012 non-null  float64
#  3   rating_number   1610012 non-null  int64
#  4   features        1610012 non-null  object
#  5   description     1610012 non-null  object
#  6   store           1600492 non-null  object
#  7   categories      1610012 non-null  object
#  8   details         1610012 non-null  object
#  9   parent_asin     1610012 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 122.8+ MB

# %%
meta.loc[meta["main_category"].isna(),["categories", "title"]].head(10)
# Out:
#                                             categories  \
# 9    [Electronics, Car & Vehicle Electronics, Marin...
# 91   [Electronics, Car & Vehicle Electronics, Aviat...
# 149  [Electronics, Computers & Accessories, Laptop ...
# 314  [Electronics, Computers & Accessories, Laptop ...
# 368  [Electronics, Computers & Accessories, Laptop ...
# 434  [Electronics, Computers & Accessories, Laptop ...
# 504  [Electronics, Camera & Photo, Underwater Photo...
# 647  [Electronics, Portable Audio & Video, Portable...
# 748  [Electronics, Car & Vehicle Electronics, Marin...
# 978  [Electronics, Computers & Accessories, Laptop ...
#
#                                                  title
# 9    Fishfinder, Depth Finder Poly Sun Cover for 3"...
# 91              AirClassics Flight Bag | ASA-BAG-FLT-1
# 149  LOVEVOOK Laptop Backpack for Women Work Travel...
# 314  Advocator Slim Business Backpack for Laptop Up...
# 368  DHK Leather Backpack Vintage Laptop Bookbag fo...
# 434  Leather 15.6 inch Laptop Backpack Hiking Campi...
# 504  DIVEROID Waterproof Phone Case – Easy to Use U...
# 647  Ultimate Ears MEGABLAST Portable Waterproof Wi...
# 748  Simrad 000-14077-001 GO7 XSR Chartplotter/Fish...
# 978  BAGEIRA Travel Backpack for Men Women, 15.6 La...

# %%
missing_mask_cat = meta['main_category'].isna()
meta.loc[missing_mask_cat,'main_category'] = meta.loc[
    missing_mask_cat,'categories'
].apply(lambda x: x[0]
        if isinstance(x,(list,tuple,np.ndarray)) and len(x)>0
        else np.nan)

# %%
meta["main_category"].isna().sum()
# Out:
# np.int64(0)

# %%
meta.isna().sum()
# Out:
# main_category     106334
# title                  0
# average_rating         0
# rating_number          0
# features               0
# description            0
# store               9520
# categories             0
# details                0
# parent_asin            0
# dtype: int64
